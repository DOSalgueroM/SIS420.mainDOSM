# %%
import sys
sys.path.append('/content/gdrive/MyDrive/Colab Notebooks/SIS420/Busquedas')
                 
#from Nodos import Nodo
#DAVNIA OSMARA SALGUERO MENCIAS

# %%
class Nodo:
    def __init__(self, estado, hijo=None):
        self.estado = estado
        self.hijo = []
        self.padre = []
        self.accion = None
        self.acciones = None
        self.costo = None
        self.set_hijo(hijo)

    def set_estado(self, estado):
        self.estado = estado

    def get_estado(self):
        return self.estado

    def set_hijo(self, hijo):
        self.hijo = hijo
        if self.hijo is not None:
            for s in self.hijo:
                s.padre = self
    # def set_hijo(self, hijo):
    #     if (hijo is not None):
    #         self.hijo.append(hijo)
    #         if self.hijo is not None:
    #             for h in self.hijo:
    #                 h.padre = self

    def get_hijo(self):
        return self.hijo
    
    def set_padre(self, padre):
        self.padre = padre

    def get_padre(self):
        return self.padre
    
    def set_accion(self, accion):
        self.accion = accion

    def get_accion(self):
        return self.accion

    def set_acciones(self, acciones):
        self.acciones = acciones

    def get_acciones(self):
        return self.acciones

    def set_costo(self, costo):
        self.costo = costo

    def get_costo(self):
        return self.costo

    def equal(self, Nodo):
        if self.get_estado() == Nodo.get_estado():
            return True
        else:
            return False

    def en_lista(self, lista_nodos):
        enlistado = False
        for n in lista_nodos:
            if self.equal(n):
                enlistado = True
        return enlistado

    def __str__(self):
        return str(self.get_estado())

# %%
# def generar_sucesores(estado):
#     sucesores = []
#     estado_lista = estado.split("\n")
#     for i in range(len(estado_lista)):
#         if estado_lista[i] == "  /\\  ":
#             sucesor = estado_lista[:i] + [" /\\ ", "/  \\\\", " \\  / ", "  \\/  "] + estado_lista[i+1:]
#             sucesores.append("\n".join(sucesor))
#         elif estado_lista[i] == " /  \\\\":
#             sucesor = estado_lista[:i] + ["\\/  ", "    /\\", "   /  \\", "  /    \\\\", " /      ", "/\\      "] + estado_lista[i+1:]
#             sucesores.append("\n".join(sucesor))
#         elif estado_lista[i] == " \\  / ":
#             sucesor = estado_lista[:i] + ["  /\\  ", " /  \\\\", "/    \\\\", "      /", "      \\/"] + estado_lista[i+1:]
#             sucesores.append("\n".join(sucesor))
#         elif estado_lista[i] == "  \\/  ":
#             sucesor = estado_lista[:i] + [" /  \\", "/    \\", "      \\", "      /", "  \\/  ", " /  \\\\"] + estado_lista[i+1:]
#             sucesores.append("\n".join(sucesor))
#     return sucesores


def busqueda_BPPR(nodo_inicial, solucion, visitado):
    visitado.append(nodo_inicial.get_estado())
    #sucesores = generar_sucesores(nodo_inicial.get_estado())
    if nodo_inicial.get_estado() == solucion:
        return nodo_inicial
    else:
        sucesores = []
        estado_lista = nodo_inicial.get_estado().split("\n")
        for i in range(len(estado_lista)):
            if estado_lista[i] == "  /\\  ":
                sucesor = estado_lista[:i] + [" /\\ ", "/  \\\\", " \\  / ", "  \\/  "] + estado_lista[i+1:]
                sucesor1 = Nodo("\n".join(sucesor))
                #nodo_inicial.set_hijo(sucesor1)
                #nodo_inicial.set_hijo(sucesores)
            elif estado_lista[i] == " /  \\\\":
                sucesor = estado_lista[:i] + ["\\/  ", "    /\\", "   /  \\", "  /    \\\\", " /      ", "/\\      "] + estado_lista[i+1:]
                sucesor2 = Nodo("\n".join(sucesor))
                #nodo_inicial.set_hijo(sucesor2)
                #sucesores.append("\n".join(sucesor))
                #nodo_inicial.set_hijo(sucesores)
                #nodo_inicial.set_hijo("\n".join(sucesor))
            elif estado_lista[i] == " \\  / ":
                sucesor = estado_lista[:i] + ["  /\\  ", " /  \\\\", "/    \\\\", "      /", "      \\/"] + estado_lista[i+1:]
                sucesor3 = Nodo("\n".join(sucesor))
                #nodo_inicial.set_hijo(sucesor3)
                #sucesores.append("\n".join(sucesor))
                #nodo_inicial.set_hijo(sucesores)
                #nodo_inicial.set_hijo("\n".join(sucesor))
            elif estado_lista[i] == "  \\/  ":
                sucesor = estado_lista[:i] + [" /  \\", "/    \\", "      \\", "      /", "  \\/  ", " /  \\\\"] + estado_lista[i+1:]
                sucesor4 = Nodo("\n".join(sucesor))
                #nodo_inicial.set_hijo(sucesor4)
                #sucesores.append("\n".join(sucesor))
                #nodo_inicial.set_hijo(sucesores)
                #nodo_inicial.set_hijo("\n".join(sucesor)
            nodo_inicial.set_hijo([sucesor1, sucesor2, sucesor3, sucesor4])
        for nodo_hijo in nodo_inicial.get_hijo():
            if not nodo_hijo.get_estado() in visitado:
                # Llamada Recursiva
                Solution = busqueda_BPPR(nodo_hijo, solucion, visitado)
                if Solution is not None:
                    return Solution
        return None

if __name__ == "__main__":
    # Definición del estado inicial
    estado_inicial = "    /\\    \n   /  \\   \n     /\\  \n    /  \\ \n   /    \\\n"

# Definición del estado objetivo
    solucion = "  \\/    \n /\\     \n/      \\\n        \n/\\     \n\\/     \n"
    #sucesores = generar_sucesores(estado_inicial)
    nodo_solucion = None
    visitado = []
    nodo_inicial = Nodo(estado_inicial)
    nodo_actual = busqueda_BPPR(nodo_inicial, solucion, visitado)

    # Mostrar Resultado
    resultado = []
    while nodo_actual.get_padre() is not None:
        resultado.append(nodo_actual.get_estado())
        nodo_actual = nodo_actual.get_padre()
    resultado.append(estado_inicial)
    resultado.reverse()
    print(resultado)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[21], line 74
#      72 visitado = []
#      73 nodo_inicial = Nodo(estado_inicial)
# ---> 74 nodo_actual = busqueda_BPPR(nodo_inicial, solucion, visitado)
#      76 # Mostrar Resultado
#      77 resultado = []
#
# Cell In[21], line 55, in busqueda_BPPR(nodo_inicial, solucion, visitado)
#      50         sucesor4 = Nodo("\n".join(sucesor))
#      51         #nodo_inicial.set_hijo(sucesor4)
#      52         #sucesores.append("\n".join(sucesor))
#      53         #nodo_inicial.set_hijo(sucesores)
#      54         #nodo_inicial.set_hijo("\n".join(sucesor)
# ---> 55     nodo_inicial.set_hijo([sucesor1, sucesor2, sucesor3, sucesor4])
#      56 for nodo_hijo in nodo_inicial.get_hijo():
#      57     if not nodo_hijo.get_estado() in visitado:
#      58         # Llamada Recursiva
#
# ...
