# %%
import random
import math
#davinia salguero
#https://github.com/DOSalgueroM/SIS420_DOSM/tree/main/examenes/primer%20parcial
numero_genes = 9 #La longitud del material genetico de cada individuo
tamano_poblacion = 500 #La cantidad de individuos que habra en la poblacion
precision = 30 #Cuantos individuos se seleccionan para reproduccion. Necesariamente mayor que 2
probabilidad_mutacion = 0.4 #La probabilidad de que un individuo mute
valor_minimo_gen = 1
valor_maximo_gen = 10

# %%
A = {1:9, 2 : 8, 3 : 7, 4 : 6 , 5  : 5 , 6: 4, 7 : 3, 8 : 2, 9 : 1}
#A['1']

# %%
def crear_individuo(min, max):
    # Crea un individuo
    
    # cromosoma = []
     #for i in range(numero_genes):
    cromosoma = random.sample(range(min, max),numero_genes)
    
    return cromosoma

    #return[random.sample(range(min, max),numero_genes) for i in range(numero_genes)]
    #return[random.randint(min, max) for i in range(numero_genes)]

#print(crear_individuo(1, 10))

def crear_poblacion(numero_individuos):
    # Crea una poblacion nueva de individuos
    
    return [crear_individuo(valor_minimo_gen, valor_maximo_gen) for i in range(numero_individuos)]

# poblacion_prueba = crear_poblacion(5)
# print(poblacion_prueba)

def calcular_fitness(individuo):
    # aptitud = 0
    # for i in range(numero_genes - 1):
    #     if abs(int(individuo[i]) - int(individuo[i+1])) > 1:
    #         aptitud += 1
    # return aptitud
    distance = 0
    for i in range(len(individuo) - 1):
        distance += abs(individuo[i] - individuo[i + 1])
    return distance
    #print(individuo)
    # i = 0
    # k = 0  
    # acumulador = 0
    # print("error")
    # print(individuo)
    # while i<4:
    #     min1 = individuo[k]
    #     k+=1
    #     max1 = individuo[k]
    #     #A[min1] = 2
    #     if A[min1] == max1:
    #         acumulador-=10
    #     else:
    #         acumulador=1000 
    #     k+=1
    #     i+=1
    # return acumulador
    

    #min = individuo[0]
    #max=individuo[1]
    #if A[min] == max:
    #    return 0
    #return 1000
    # distancia = 0
    # for i in range(numero_genes - 1):
    #     pos_actual = individuo[i]
    #     pos_siguiente = individuo[i+1]
    #     distancia += abs(pos_actual[0] - pos_siguiente[0]) + abs(pos_actual[1] - pos_siguiente[1])
    # #Retorna la inversa de la distancia total para maximizarla
    # return distancia
    # aptitud = 0
    # for i in range(numero_genes - 1):
    #     if abs(individuo[i] - individuo[i+1]) > 1:
    #         aptitud += 1
    # return aptitud

# print(calcular_fitness(poblacion_prueba[0]))

# %%
# funcion empleada para ordenar la poblacion
def ordenar_por_segundo_elemento(elem):
    return elem[1]

# %%
# poblacion = crear_poblacion(tamano_poblacion)
# poblacion_evaluada = [(i, calcular_fitness(i)) for i in poblacion ]
# poblacion_ordenada  = sorted(poblacion_evaluada, key=ordenar_por_segundo_elemento)
# poblacion = [i[0] for i in poblacion_ordenada]

# for ind in poblacion_ordenada:
#   print(f"individuo: {ind[0]} fitness: {ind[1]}")

# print("###"*3)

# for ind in poblacion:
#   print(f"individuo: {ind} fitness: {calcular_fitness(ind)}")

# %%
def seleccion_y_reproduccion(poblacion):
  # Puntua todos los elementos de la poblacion (population) y se queda con los mejores guardandolos dentro de 'seleccionados'.
  # Despues mezcla el material genetico de los elegidos para crear nuevos individuos y llenar la poblacion 
  # (guardando tambien una copia de los individuos seleccionados sin modificar).
  # Por ultimo se aplica la mutacion a los individuos.
  print("poblacion")
  print(poblacion)
  poblacion_evaluada = [(indiv, calcular_fitness(indiv)) for indiv in poblacion ] #Calcula el fitness de cada individuo, y lo guarda en pares ordenados de la forma (5 , [1,2,1,1,4,1,8,9,4,1])
  poblacion_ordenada  = [indiv[0] for indiv in sorted(poblacion_evaluada, key=ordenar_por_segundo_elemento)] #Ordena los pares ordenados y se queda solo con el array de valores
  
  poblacion = poblacion_ordenada
  #poblacion_seleccionada = poblacion_ordenada[(len(poblacion_ordenada) - precision):] #Esta linea selecciona los 'n' individuos del final, donde n viene dado por 'precision'
  poblacion_seleccionada = poblacion_ordenada[precision:] #Esta linea selecciona los 'n' individuos del final, donde n viene dado por 'precision'
  #Se mezcla el material genetico para crear nuevos individuos
  for i in range(precision, len(poblacion)):
    punto_cruce = random.randint(1, numero_genes - 1) #Se elige un punto para hacer el intercambio
    padre = random.sample(poblacion_seleccionada, 2) #Se eligen dos padres
    poblacion[i][:punto_cruce] = padre[0][:punto_cruce] #Se mezcla el material genetico de los padres en cada nuevo individuo
    poblacion[i][punto_cruce:] = padre[1][punto_cruce:]
  
  return poblacion #El array 'poblacion' tiene ahora una nueva poblacion de individuos, que se devuelven

# %%
# poblacion = crear_poblacion(tamano_poblacion)
# poblacion = seleccion_y_reproduccion(poblacion)
# poblacion_evaluada = [(i, calcular_fitness(i)) for i in poblacion ]
# poblacion_ordenada  = sorted(poblacion_evaluada, key=ordenar_por_segundo_elemento)
# poblacion = [i[0] for i in poblacion_ordenada]

# for ind in poblacion_ordenada:
#   print(f"individuo: {ind[0]} fitness: {ind[1]}")

# %%
def mutacion(poblacion):
  #Se mutan los individuos al azar. Sin la mutacion de nuevos genes nunca podriavalcanzarse la solucion.
   
  for i in range(precision, len(poblacion)):
    if random.random() <= probabilidad_mutacion: #Cada individuo de la poblacion (menos los padres) tienen una probabilidad de mutar
      punto = random.randint(0, numero_genes - 1) #Se elgie un punto al azar
      nuevo_valor = random.sample(range(valor_minimo_gen, valor_maximo_gen),numero_genes) #y un nuevo valor para este punto
  
      #Es importante mirar que el nuevo valor no sea igual al viejo
      while nuevo_valor == poblacion[i][punto]:
          nuevo_valor = random.sample(range(valor_minimo_gen, valor_maximo_gen),numero_genes)
  
      #Se aplica la mutacion
      poblacion[i][punto] = nuevo_valor
  
  return poblacion

# %%
# poblacion = mutacion(poblacion)
# poblacion_evaluada = [(i, calcular_fitness(i)) for i in poblacion ]
# poblacion_ordenada  = sorted(poblacion_evaluada, key=ordenar_por_segundo_elemento)

# for ind in poblacion_ordenada:
#   print(f"individuo: {ind[0]} fitness: {ind[1]}")

# %%
poblacion = crear_poblacion(tamano_poblacion)#Inicializar una poblacion
print("Poblacion Inicial:") #Se muestra la poblacion inicial
poblacion_evaluada = [(i, calcular_fitness(i)) for i in poblacion ]
poblacion_ordenada  = sorted(poblacion_evaluada, key=ordenar_por_segundo_elemento)

for ind in poblacion_ordenada:
  print(f"individuo: {ind[0]} fitness: {ind[1]}")

numero_generaciones = 1000
mejor_fitness = 10000
numero_generacion = 0;
break_out_flag = False
#Se evoluciona la poblacion
for i in range(numero_generaciones):
    puntuados = [ (ind, calcular_fitness(ind)) for ind in poblacion] 
    numero_generacion = numero_generacion + 1
    for indPun in puntuados:
      if indPun[1] < mejor_fitness:
        mejor_fitness = indPun[1]
      if indPun[1] == 0:
        break_out_flag = True
        break

    if break_out_flag:
        break

    poblacion = seleccion_y_reproduccion(poblacion)
    poblacion = mutacion(poblacion)

    poblacion_evaluada = [(i, calcular_fitness(i)) for i in poblacion ]
    poblacion_ordenada  = sorted(poblacion_evaluada, key=ordenar_por_segundo_elemento)

    print(f"generacion no: {numero_generacion}")
    for ind in poblacion_ordenada:
      print(f"individuo: {ind[0]} fitness: {ind[1]}")


print("Poblacion final:")

poblacion_evaluada = [(i, calcular_fitness(i)) for i in poblacion ]
poblacion_ordenada  = sorted(poblacion_evaluada, key=ordenar_por_segundo_elemento)

for ind in poblacion_ordenada:
  print(f"individuo: {ind[0]} fitness: {ind[1]}")

# print("\nPoblacion Final que cuenta con una solucion:\n%s"%(poblacion)) #Se muestra la poblacion evolucionada
# print("\n\n")

if mejor_fitness == 0:
  individuo = poblacion_ordenada[0][0]
  print(f"El mejor fenotipo que resuelve la ecuacion es:{individuo}")
  #print(f"La solucion a la ecuacion 2X1 + 5X2² - X3 + X4 - 8X5 - 10 = 0 es {2 * individuo[0]} + {5 * individuo[1]**2} - {individuo[2]} + {individuo[3]} - {8 * individuo[4]} -10 = 0")
  print(f"la solucion se encontro en la {numero_generacion} generación")
else:
  print("El algoritmo no pudo encontrar una solucion")
# Out:
# Poblacion Inicial:
# individuo: [1, 2, 3, 4, 6, 8, 5, 7, 9] fitness: 14
# individuo: [8, 9, 3, 2, 1, 4, 5, 6, 7] fitness: 15
# individuo: [1, 2, 6, 4, 3, 5, 8, 7, 9] fitness: 16
# individuo: [3, 2, 7, 8, 9, 6, 5, 4, 1] fitness: 16
# individuo: [7, 8, 9, 3, 4, 5, 6, 2, 1] fitness: 16
# individuo: [9, 8, 6, 3, 1, 2, 4, 7, 5] fitness: 16
# individuo: [9, 7, 8, 3, 2, 1, 6, 5, 4] fitness: 17
# individuo: [8, 9, 7, 2, 4, 5, 6, 3, 1] fitness: 17
# individuo: [4, 1, 2, 5, 3, 6, 9, 8, 7] fitness: 17
# individuo: [9, 7, 5, 6, 3, 2, 1, 4, 8] fitness: 17
# individuo: [1, 2, 3, 8, 6, 7, 9, 5, 4] fitness: 17
# individuo: [7, 8, 5, 3, 4, 2, 1, 6, 9] fitness: 18
# individuo: [8, 9, 7, 3, 1, 6, 5, 4, 2] fitness: 18
# individuo: [1, 3, 6, 4, 5, 2, 7, 8, 9] fitness: 18
# individuo: [2, 4, 6, 3, 1, 5, 7, 9, 8] fitness: 18
# individuo: [9, 6, 3, 1, 2, 4, 8, 7, 5] fitness: 18
# individuo: [9, 8, 2, 3, 4, 1, 5, 6, 7] fitness: 18
# individuo: [6, 3, 9, 8, 7, 5, 4, 1, 2] fitness: 18
# individuo: [9, 5, 1, 3, 2, 4, 7, 8, 6] fitness: 19
# individuo: [8, 6, 3, 4, 7, 9, 5, 2, 1] fitness: 19
# individuo: [2, 3, 7, 6, 5, 9, 8, 4, 1] fitness: 19
# individuo: [3, 5, 6, 7, 1, 2, 4, 9, 8] fitness: 19
# individuo: [8, 9, 3, 1, 2, 5, 6, 4, 7] fitness: 19
# individuo: [1, 2, 4, 9, 7, 6, 3, 5, 8] fitness: 19
# individuo: [2, 1, 3, 8, 9, 6, 4, 7, 5] fitness: 19
# individuo: [3, 6, 4, 7, 9, 8, 5, 1, 2] fitness: 19
# individuo: [2, 1, 8, 6, 4, 3, 5, 7, 9] fitness: 19
# individuo: [2, 4, 6, 5, 1, 3, 9, 8, 7] fitness: 19
# individuo: [7, 4, 6, 2, 1, 3, 5, 9, 8] fitness: 19
# individuo: [1, 2, 3, 8, 5, 9, 7, 6, 4] fitness: 19
# individuo: [1, 2, 8, 6, 9, 7, 4, 5, 3] fitness: 20
# individuo: [7, 3, 4, 2, 1, 6, 8, 9, 5] fitness: 20
# individuo: [6, 7, 3, 2, 1, 9, 8, 5, 4] fitness: 20
# individuo: [8, 6, 4, 3, 7, 9, 5, 1, 2] fitness: 20
# individuo: [3, 2, 1, 6, 4, 9, 7, 8, 5] fitness: 20
# individuo: [5, 9, 7, 6, 8, 2, 4, 3, 1] fitness: 20
# individuo: [7, 4, 1, 2, 6, 3, 5, 8, 9] fitness: 20
# individuo: [5, 8, 7, 3, 4, 2, 1, 6, 9] fitness: 20
# individuo: [3, 2, 8, 9, 7, 4, 6, 5, 1] fitness: 20
# individuo: [9, 1, 2, 4, 3, 6, 7, 8, 5] fitness: 20
# individuo: [3, 7, 8, 1, 2, 4, 5, 6, 9] fitness: 20
# individuo: [9, 3, 1, 4, 2, 5, 6, 8, 7] fitness: 20
# individuo: [8, 9, 3, 7, 6, 5, 1, 2, 4] fitness: 20
# individuo: [7, 4, 3, 2, 1, 6, 8, 5, 9] fitness: 20
# individuo: [9, 8, 5, 7, 3, 6, 2, 1, 4] fitness: 21
# individuo: [5, 7, 9, 8, 1, 3, 2, 6, 4] fitness: 21
# individuo: [2, 6, 7, 8, 5, 9, 4, 3, 1] fitness: 21
# individuo: [2, 3, 4, 6, 8, 7, 5, 9, 1] fitness: 21
# individuo: [9, 5, 1, 2, 3, 7, 6, 4, 8] fitness: 21
# individuo: [3, 2, 1, 7, 9, 5, 6, 8, 4] fitness: 21
# individuo: [4, 2, 6, 7, 8, 9, 3, 5, 1] fitness: 21
# individuo: [2, 1, 3, 8, 6, 5, 7, 4, 9] fitness: 21
# individuo: [7, 4, 5, 8, 9, 1, 2, 3, 6] fitness: 21
# individuo: [6, 9, 8, 2, 3, 1, 5, 4, 7] fitness: 21
# individuo: [1, 5, 3, 7, 8, 9, 6, 2, 4] fitness: 21
# individuo: [1, 7, 9, 8, 5, 3, 4, 2, 6] fitness: 21
# individuo: [5, 8, 9, 3, 1, 2, 6, 7, 4] fitness: 21
# individuo: [6, 4, 1, 5, 8, 9, 7, 2, 3] fitness: 21
# individuo: [2, 5, 1, 4, 6, 7, 9, 8, 3] fitness: 21
# individuo: [4, 5, 6, 7, 3, 9, 8, 2, 1] fitness: 21
# individuo: [2, 8, 7, 9, 6, 3, 1, 4, 5] fitness: 21
# individuo: [2, 9, 8, 5, 1, 3, 4, 6, 7] fitness: 21
# individuo: [7, 9, 2, 1, 5, 4, 3, 6, 8] fitness: 21
# individuo: [1, 3, 2, 9, 7, 4, 5, 8, 6] fitness: 21
# individuo: [4, 5, 7, 6, 9, 2, 1, 3, 8] fitness: 22
# individuo: [7, 6, 5, 4, 1, 9, 8, 2, 3] fitness: 22
# individuo: [7, 9, 1, 3, 2, 4, 8, 6, 5] fitness: 22
# individuo: [7, 4, 8, 6, 2, 1, 3, 5, 9] fitness: 22
# individuo: [6, 3, 7, 2, 1, 4, 5, 9, 8] fitness: 22
# individuo: [3, 1, 8, 9, 2, 4, 5, 6, 7] fitness: 22
# individuo: [7, 6, 2, 4, 8, 9, 5, 1, 3] fitness: 22
# individuo: [5, 9, 4, 6, 7, 8, 2, 3, 1] fitness: 22
# individuo: [5, 4, 6, 1, 2, 9, 8, 7, 3] fitness: 22
# individuo: [3, 2, 8, 1, 4, 5, 6, 7, 9] fitness: 22
# individuo: [2, 8, 9, 7, 5, 3, 4, 1, 6] fitness: 22
# individuo: [5, 3, 6, 8, 9, 1, 2, 4, 7] fitness: 22
# individuo: [1, 4, 8, 7, 9, 3, 2, 6, 5] fitness: 22
# individuo: [1, 5, 8, 3, 4, 2, 6, 7, 9] fitness: 22
# individuo: [6, 7, 5, 4, 1, 9, 8, 3, 2] fitness: 22
# individuo: [9, 8, 5, 6, 3, 7, 2, 4, 1] fitness: 22
# individuo: [9, 6, 7, 4, 8, 3, 5, 2, 1] fitness: 22
# individuo: [1, 8, 5, 6, 4, 2, 3, 7, 9] fitness: 22
# individuo: [2, 3, 5, 7, 1, 4, 9, 8, 6] fitness: 22
# individuo: [7, 8, 9, 3, 2, 6, 1, 4, 5] fitness: 22
# individuo: [3, 1, 2, 9, 4, 6, 8, 7, 5] fitness: 22
# individuo: [5, 1, 2, 3, 8, 4, 6, 9, 7] fitness: 22
# individuo: [6, 9, 8, 3, 7, 5, 1, 2, 4] fitness: 22
# individuo: [7, 6, 4, 3, 9, 8, 2, 1, 5] fitness: 22
# individuo: [1, 2, 4, 8, 6, 9, 5, 7, 3] fitness: 22
# individuo: [1, 2, 4, 8, 5, 6, 3, 9, 7] fitness: 22
# individuo: [7, 8, 5, 1, 2, 6, 9, 4, 3] fitness: 22
# individuo: [4, 1, 7, 8, 6, 9, 5, 3, 2] fitness: 22
# individuo: [1, 6, 8, 5, 9, 7, 3, 2, 4] fitness: 23
# individuo: [1, 4, 9, 2, 3, 6, 5, 7, 8] fitness: 23
# individuo: [4, 9, 8, 1, 2, 7, 6, 5, 3] fitness: 23
# individuo: [6, 5, 1, 2, 9, 8, 4, 3, 7] fitness: 23
# individuo: [1, 7, 3, 2, 6, 9, 8, 5, 4] fitness: 23
# individuo: [5, 1, 3, 9, 8, 6, 7, 2, 4] fitness: 23
# individuo: [7, 4, 6, 9, 8, 3, 1, 5, 2] fitness: 23
# individuo: [3, 4, 1, 9, 8, 5, 7, 6, 2] fitness: 23
# individuo: [1, 7, 6, 3, 5, 2, 4, 9, 8] fitness: 23
# individuo: [8, 3, 2, 5, 6, 4, 1, 7, 9] fitness: 23
# individuo: [8, 7, 3, 9, 5, 4, 6, 2, 1] fitness: 23
# individuo: [1, 4, 5, 9, 2, 3, 7, 8, 6] fitness: 23
# individuo: [2, 6, 1, 3, 5, 7, 4, 8, 9] fitness: 23
# individuo: [1, 3, 9, 5, 4, 2, 8, 7, 6] fitness: 23
# individuo: [3, 8, 9, 5, 2, 1, 6, 7, 4] fitness: 23
# individuo: [8, 9, 6, 1, 4, 2, 5, 3, 7] fitness: 23
# individuo: [1, 3, 7, 8, 5, 4, 6, 9, 2] fitness: 23
# individuo: [2, 6, 9, 7, 4, 5, 8, 3, 1] fitness: 23
# individuo: [5, 1, 4, 7, 3, 2, 6, 9, 8] fitness: 23
# individuo: [6, 5, 9, 8, 4, 2, 3, 7, 1] fitness: 23
# individuo: [9, 4, 2, 5, 1, 3, 7, 8, 6] fitness: 23
# individuo: [6, 9, 4, 2, 3, 5, 8, 7, 1] fitness: 23
# individuo: [8, 7, 6, 4, 9, 2, 1, 5, 3] fitness: 23
# individuo: [9, 6, 3, 4, 7, 5, 1, 2, 8] fitness: 23
# individuo: [8, 5, 1, 7, 9, 6, 4, 2, 3] fitness: 23
# individuo: [6, 9, 8, 3, 7, 1, 2, 4, 5] fitness: 23
# individuo: [1, 9, 8, 6, 3, 7, 5, 4, 2] fitness: 23
# individuo: [9, 7, 3, 5, 6, 4, 8, 1, 2] fitness: 23
# individuo: [6, 4, 9, 7, 8, 3, 2, 5, 1] fitness: 23
# individuo: [2, 7, 3, 1, 5, 6, 4, 8, 9] fitness: 23
# individuo: [5, 9, 7, 1, 4, 3, 2, 6, 8] fitness: 23
# individuo: [5, 6, 8, 7, 3, 4, 9, 1, 2] fitness: 23
# individuo: [7, 9, 3, 1, 4, 5, 6, 8, 2] fitness: 23
# individuo: [1, 7, 6, 9, 5, 4, 3, 2, 8] fitness: 23
# individuo: [2, 9, 6, 8, 7, 3, 5, 4, 1] fitness: 23
# individuo: [3, 2, 5, 1, 7, 4, 6, 9, 8] fitness: 23
# individuo: [6, 7, 9, 1, 3, 2, 4, 8, 5] fitness: 23
# individuo: [9, 5, 1, 8, 7, 6, 3, 2, 4] fitness: 23
# individuo: [8, 6, 1, 3, 4, 2, 7, 5, 9] fitness: 23
# individuo: [2, 3, 8, 9, 1, 4, 6, 5, 7] fitness: 23
# individuo: [7, 6, 5, 8, 2, 4, 1, 3, 9] fitness: 24
# individuo: [5, 1, 4, 6, 8, 9, 2, 3, 7] fitness: 24
# individuo: [1, 8, 7, 9, 4, 6, 2, 3, 5] fitness: 24
# individuo: [9, 8, 2, 6, 1, 3, 4, 7, 5] fitness: 24
# individuo: [9, 1, 2, 8, 6, 3, 4, 5, 7] fitness: 24
# individuo: [3, 1, 6, 8, 4, 5, 2, 7, 9] fitness: 24
# individuo: [4, 2, 7, 1, 3, 6, 5, 9, 8] fitness: 24
# individuo: [4, 2, 9, 7, 6, 3, 1, 5, 8] fitness: 24
# individuo: [4, 1, 7, 9, 5, 8, 6, 3, 2] fitness: 24
# individuo: [7, 4, 8, 9, 1, 2, 5, 6, 3] fitness: 24
# individuo: [9, 4, 6, 5, 2, 1, 7, 8, 3] fitness: 24
# individuo: [8, 5, 4, 7, 9, 2, 3, 1, 6] fitness: 24
# individuo: [1, 6, 9, 3, 2, 4, 8, 7, 5] fitness: 24
# individuo: [4, 1, 3, 7, 9, 5, 8, 6, 2] fitness: 24
# individuo: [5, 3, 9, 1, 2, 4, 6, 8, 7] fitness: 24
# individuo: [9, 6, 8, 3, 4, 2, 7, 5, 1] fitness: 24
# individuo: [3, 6, 4, 8, 7, 5, 9, 2, 1] fitness: 24
# individuo: [4, 9, 7, 8, 1, 6, 5, 3, 2] fitness: 24
# individuo: [3, 1, 5, 8, 2, 4, 6, 9, 7] fitness: 24
# individuo: [1, 4, 8, 7, 6, 3, 5, 2, 9] fitness: 24
# individuo: [3, 2, 6, 4, 1, 8, 5, 7, 9] fitness: 24
# individuo: [9, 4, 3, 8, 7, 2, 1, 6, 5] fitness: 24
# individuo: [3, 2, 5, 1, 7, 8, 4, 6, 9] fitness: 24
# individuo: [4, 9, 7, 6, 3, 5, 1, 2, 8] fitness: 24
# individuo: [1, 7, 6, 2, 4, 3, 8, 9, 5] fitness: 24
# individuo: [3, 9, 6, 8, 4, 2, 1, 5, 7] fitness: 24
# individuo: [8, 9, 5, 2, 1, 7, 3, 6, 4] fitness: 24
# individuo: [6, 3, 5, 2, 1, 8, 7, 4, 9] fitness: 25
# individuo: [3, 2, 4, 9, 7, 1, 6, 5, 8] fitness: 25
# individuo: [1, 8, 7, 3, 4, 2, 5, 9, 6] fitness: 25
# individuo: [9, 8, 4, 5, 1, 7, 3, 2, 6] fitness: 25
# individuo: [6, 5, 9, 2, 1, 7, 8, 4, 3] fitness: 25
# individuo: [6, 9, 4, 1, 5, 2, 3, 8, 7] fitness: 25
# individuo: [6, 2, 5, 1, 9, 8, 7, 4, 3] fitness: 25
# individuo: [4, 2, 6, 1, 8, 9, 7, 5, 3] fitness: 25
# individuo: [2, 8, 6, 1, 4, 5, 3, 7, 9] fitness: 25
# individuo: [9, 2, 6, 7, 4, 1, 3, 5, 8] fitness: 25
# individuo: [8, 5, 1, 7, 9, 6, 2, 4, 3] fitness: 25
# individuo: [3, 6, 1, 2, 8, 9, 5, 7, 4] fitness: 25
# individuo: [1, 5, 2, 9, 6, 3, 4, 7, 8] fitness: 25
# individuo: [4, 1, 6, 9, 5, 2, 3, 8, 7] fitness: 25
# individuo: [6, 9, 4, 1, 5, 3, 2, 8, 7] fitness: 25
# individuo: [6, 8, 3, 1, 4, 2, 7, 9, 5] fitness: 25
# individuo: [5, 4, 2, 3, 7, 1, 8, 9, 6] fitness: 25
# individuo: [6, 9, 8, 2, 4, 7, 3, 5, 1] fitness: 25
# individuo: [4, 9, 5, 2, 1, 6, 7, 8, 3] fitness: 25
# individuo: [3, 9, 8, 7, 1, 5, 6, 2, 4] fitness: 25
# individuo: [1, 5, 7, 4, 9, 8, 3, 2, 6] fitness: 25
# individuo: [6, 2, 1, 3, 7, 9, 4, 8, 5] fitness: 25
# individuo: [2, 7, 6, 5, 4, 1, 9, 8, 3] fitness: 25
# individuo: [2, 3, 6, 5, 7, 8, 4, 9, 1] fitness: 25
# individuo: [5, 7, 8, 1, 3, 9, 6, 4, 2] fitness: 25
# individuo: [7, 9, 3, 6, 5, 8, 2, 1, 4] fitness: 25
# individuo: [4, 5, 6, 2, 1, 8, 3, 7, 9] fitness: 25
# individuo: [9, 4, 3, 7, 5, 6, 1, 2, 8] fitness: 25
# individuo: [7, 3, 5, 4, 9, 8, 2, 1, 6] fitness: 25
# individuo: [4, 6, 1, 9, 8, 7, 3, 2, 5] fitness: 25
# individuo: [3, 7, 5, 4, 8, 9, 2, 1, 6] fitness: 25
# individuo: [7, 1, 6, 8, 9, 3, 5, 4, 2] fitness: 25
# individuo: [5, 3, 6, 1, 2, 8, 7, 9, 4] fitness: 25
# individuo: [7, 6, 2, 1, 4, 9, 3, 5, 8] fitness: 25
# individuo: [1, 7, 6, 3, 8, 9, 5, 2, 4] fitness: 25
# individuo: [3, 5, 6, 2, 1, 9, 4, 7, 8] fitness: 25
# individuo: [5, 6, 8, 4, 1, 3, 9, 7, 2] fitness: 25
# individuo: [2, 9, 7, 6, 4, 5, 8, 1, 3] fitness: 25
# individuo: [9, 4, 6, 7, 1, 2, 5, 3, 8] fitness: 25
# individuo: [2, 5, 3, 4, 8, 1, 6, 7, 9] fitness: 25
# individuo: [4, 9, 6, 8, 5, 2, 3, 1, 7] fitness: 25
# individuo: [9, 7, 2, 5, 8, 1, 3, 4, 6] fitness: 25
# individuo: [5, 8, 9, 3, 2, 6, 7, 1, 4] fitness: 25
# individuo: [1, 5, 2, 4, 7, 3, 8, 9, 6] fitness: 25
# individuo: [1, 7, 9, 5, 8, 4, 6, 3, 2] fitness: 25
# individuo: [6, 3, 1, 7, 2, 5, 4, 8, 9] fitness: 25
# individuo: [7, 3, 2, 1, 8, 5, 6, 9, 4] fitness: 25
# individuo: [5, 7, 1, 8, 9, 6, 3, 4, 2] fitness: 25
# individuo: [6, 9, 1, 2, 7, 8, 4, 3, 5] fitness: 25
# individuo: [3, 7, 9, 6, 8, 1, 5, 4, 2] fitness: 25
# individuo: [8, 5, 9, 7, 1, 6, 4, 2, 3] fitness: 25
# individuo: [5, 7, 3, 9, 8, 4, 1, 2, 6] fitness: 25
# individuo: [8, 4, 5, 2, 6, 7, 9, 1, 3] fitness: 25
# individuo: [1, 2, 9, 4, 5, 8, 6, 3, 7] fitness: 26
# individuo: [9, 6, 8, 3, 1, 7, 2, 4, 5] fitness: 26
# individuo: [3, 1, 8, 2, 4, 6, 9, 7, 5] fitness: 26
# individuo: [8, 6, 7, 1, 5, 4, 9, 3, 2] fitness: 26
# individuo: [8, 9, 2, 5, 7, 1, 4, 3, 6] fitness: 26
# individuo: [3, 6, 1, 7, 2, 4, 5, 8, 9] fitness: 26
# individuo: [2, 3, 8, 7, 6, 1, 5, 9, 4] fitness: 26
# individuo: [4, 1, 8, 9, 5, 3, 7, 6, 2] fitness: 26
# individuo: [7, 4, 1, 8, 9, 2, 3, 6, 5] fitness: 26
# individuo: [7, 6, 9, 1, 2, 8, 3, 4, 5] fitness: 26
# individuo: [2, 8, 6, 7, 5, 9, 1, 3, 4] fitness: 26
# individuo: [3, 1, 4, 8, 6, 9, 2, 5, 7] fitness: 26
# individuo: [9, 1, 3, 5, 8, 2, 4, 6, 7] fitness: 26
# individuo: [3, 1, 6, 4, 8, 9, 2, 5, 7] fitness: 26
# individuo: [2, 1, 8, 3, 6, 5, 7, 9, 4] fitness: 26
# individuo: [7, 3, 2, 4, 8, 6, 5, 1, 9] fitness: 26
# individuo: [9, 3, 4, 8, 7, 2, 6, 5, 1] fitness: 26
# individuo: [6, 7, 4, 3, 9, 5, 1, 2, 8] fitness: 26
# individuo: [2, 6, 5, 3, 7, 4, 1, 9, 8] fitness: 26
# individuo: [9, 6, 2, 3, 7, 4, 8, 5, 1] fitness: 26
# individuo: [5, 8, 1, 2, 7, 3, 4, 6, 9] fitness: 26
# individuo: [4, 7, 2, 1, 5, 9, 8, 3, 6] fitness: 26
# individuo: [3, 2, 8, 5, 7, 1, 4, 6, 9] fitness: 26
# individuo: [1, 5, 2, 7, 3, 4, 8, 6, 9] fitness: 26
# individuo: [2, 7, 9, 8, 1, 5, 3, 6, 4] fitness: 26
# individuo: [8, 2, 4, 9, 7, 1, 3, 5, 6] fitness: 26
# individuo: [6, 9, 8, 3, 7, 1, 4, 5, 2] fitness: 26
# individuo: [6, 2, 4, 9, 5, 3, 1, 7, 8] fitness: 26
# individuo: [9, 4, 2, 6, 8, 5, 7, 1, 3] fitness: 26
# individuo: [8, 9, 3, 5, 6, 1, 4, 7, 2] fitness: 26
# individuo: [5, 4, 6, 1, 3, 7, 2, 8, 9] fitness: 26
# individuo: [5, 7, 6, 1, 4, 2, 9, 8, 3] fitness: 26
# individuo: [7, 9, 4, 8, 3, 1, 5, 6, 2] fitness: 27
# individuo: [1, 5, 7, 4, 8, 9, 3, 6, 2] fitness: 27
# individuo: [3, 1, 9, 6, 8, 4, 5, 7, 2] fitness: 27
# individuo: [1, 5, 8, 4, 9, 7, 3, 2, 6] fitness: 27
# individuo: [6, 9, 1, 7, 8, 4, 5, 2, 3] fitness: 27
# individuo: [4, 6, 8, 9, 3, 7, 2, 5, 1] fitness: 27
# individuo: [8, 3, 1, 4, 9, 2, 5, 6, 7] fitness: 27
# individuo: [3, 2, 6, 4, 5, 9, 1, 7, 8] fitness: 27
# individuo: [6, 8, 5, 4, 9, 2, 3, 1, 7] fitness: 27
# individuo: [1, 3, 5, 9, 2, 7, 4, 6, 8] fitness: 27
# individuo: [8, 9, 1, 6, 2, 5, 4, 3, 7] fitness: 27
# individuo: [4, 1, 6, 7, 8, 3, 5, 2, 9] fitness: 27
# individuo: [3, 1, 7, 4, 2, 6, 9, 5, 8] fitness: 27
# individuo: [1, 8, 6, 7, 2, 3, 9, 5, 4] fitness: 27
# individuo: [5, 6, 8, 7, 2, 3, 9, 1, 4] fitness: 27
# individuo: [9, 7, 4, 3, 5, 2, 6, 1, 8] fitness: 27
# individuo: [2, 9, 4, 8, 6, 7, 5, 1, 3] fitness: 27
# individuo: [6, 2, 1, 7, 5, 8, 4, 3, 9] fitness: 27
# individuo: [6, 3, 4, 5, 9, 8, 2, 7, 1] fitness: 27
# individuo: [8, 9, 1, 7, 4, 2, 5, 6, 3] fitness: 27
# individuo: [3, 2, 7, 9, 1, 5, 6, 4, 8] fitness: 27
# individuo: [6, 3, 5, 7, 8, 2, 4, 1, 9] fitness: 27
# individuo: [3, 6, 9, 5, 1, 8, 7, 4, 2] fitness: 27
# individuo: [2, 7, 1, 5, 3, 6, 4, 8, 9] fitness: 27
# individuo: [8, 9, 1, 7, 2, 4, 5, 6, 3] fitness: 27
# individuo: [3, 4, 1, 9, 5, 2, 7, 8, 6] fitness: 27
# individuo: [1, 8, 2, 6, 9, 7, 5, 3, 4] fitness: 27
# individuo: [6, 1, 3, 8, 7, 2, 5, 4, 9] fitness: 27
# individuo: [1, 5, 7, 8, 3, 2, 9, 4, 6] fitness: 27
# individuo: [7, 8, 1, 5, 3, 2, 6, 9, 4] fitness: 27
# individuo: [1, 5, 4, 2, 9, 3, 7, 8, 6] fitness: 27
# individuo: [8, 4, 7, 2, 1, 9, 6, 5, 3] fitness: 27
# individuo: [6, 1, 5, 8, 7, 3, 4, 2, 9] fitness: 27
# individuo: [2, 4, 9, 6, 8, 3, 7, 5, 1] fitness: 27
# individuo: [2, 9, 6, 3, 1, 4, 8, 5, 7] fitness: 27
# individuo: [4, 5, 3, 1, 8, 6, 2, 9, 7] fitness: 27
# individuo: [3, 1, 9, 2, 4, 7, 6, 5, 8] fitness: 27
# individuo: [8, 5, 6, 1, 2, 9, 3, 4, 7] fitness: 27
# individuo: [6, 9, 8, 3, 7, 1, 4, 2, 5] fitness: 27
# individuo: [8, 2, 3, 9, 4, 7, 6, 5, 1] fitness: 27
# individuo: [2, 7, 3, 5, 4, 6, 1, 8, 9] fitness: 27
# individuo: [3, 2, 7, 8, 5, 9, 4, 1, 6] fitness: 27
# individuo: [1, 7, 9, 5, 6, 2, 4, 8, 3] fitness: 28
# individuo: [8, 5, 2, 3, 7, 9, 1, 6, 4] fitness: 28
# individuo: [8, 1, 5, 9, 6, 4, 7, 3, 2] fitness: 28
# individuo: [1, 6, 8, 3, 9, 7, 4, 2, 5] fitness: 28
# individuo: [3, 8, 7, 2, 9, 5, 6, 4, 1] fitness: 28
# individuo: [3, 1, 8, 4, 2, 9, 5, 6, 7] fitness: 28
# individuo: [1, 8, 2, 9, 7, 6, 3, 4, 5] fitness: 28
# individuo: [2, 9, 4, 1, 3, 8, 5, 7, 6] fitness: 28
# individuo: [6, 7, 3, 5, 1, 2, 9, 4, 8] fitness: 28
# individuo: [1, 6, 2, 5, 9, 8, 4, 7, 3] fitness: 28
# individuo: [8, 4, 3, 1, 5, 7, 2, 9, 6] fitness: 28
# individuo: [1, 8, 6, 3, 4, 9, 7, 2, 5] fitness: 28
# individuo: [3, 7, 8, 2, 5, 6, 4, 1, 9] fitness: 28
# individuo: [1, 6, 3, 8, 7, 4, 5, 2, 9] fitness: 28
# individuo: [5, 4, 9, 2, 3, 7, 6, 8, 1] fitness: 28
# individuo: [7, 5, 2, 9, 8, 1, 4, 6, 3] fitness: 28
# individuo: [1, 6, 5, 2, 9, 8, 4, 7, 3] fitness: 28
# individuo: [1, 8, 5, 4, 9, 6, 2, 3, 7] fitness: 28
# individuo: [2, 7, 6, 9, 5, 1, 3, 8, 4] fitness: 28
# individuo: [3, 1, 7, 5, 2, 8, 4, 6, 9] fitness: 28
# individuo: [7, 3, 2, 8, 5, 4, 9, 6, 1] fitness: 28
# individuo: [9, 6, 5, 3, 8, 1, 4, 2, 7] fitness: 28
# individuo: [5, 1, 9, 7, 8, 4, 2, 6, 3] fitness: 28
# individuo: [7, 4, 8, 3, 2, 6, 9, 5, 1] fitness: 28
# individuo: [7, 8, 6, 2, 4, 5, 1, 9, 3] fitness: 28
# individuo: [3, 8, 9, 2, 5, 6, 4, 7, 1] fitness: 28
# individuo: [8, 6, 2, 9, 5, 7, 3, 1, 4] fitness: 28
# individuo: [6, 7, 2, 9, 8, 1, 5, 3, 4] fitness: 28
# individuo: [5, 3, 9, 7, 2, 4, 8, 6, 1] fitness: 28
# individuo: [4, 7, 3, 5, 1, 6, 8, 9, 2] fitness: 28
# individuo: [2, 8, 3, 1, 9, 7, 5, 4, 6] fitness: 28
# individuo: [3, 9, 6, 2, 1, 8, 5, 4, 7] fitness: 28
# individuo: [9, 2, 7, 4, 8, 6, 5, 1, 3] fitness: 28
# individuo: [3, 7, 9, 2, 4, 6, 5, 8, 1] fitness: 28
# individuo: [3, 6, 7, 1, 9, 8, 4, 2, 5] fitness: 28
# individuo: [1, 7, 8, 2, 9, 6, 4, 5, 3] fitness: 28
# individuo: [1, 9, 2, 3, 5, 8, 6, 4, 7] fitness: 28
# individuo: [8, 2, 9, 4, 3, 6, 7, 5, 1] fitness: 29
# individuo: [1, 2, 8, 3, 9, 4, 7, 5, 6] fitness: 29
# individuo: [1, 6, 3, 5, 8, 4, 7, 9, 2] fitness: 29
# individuo: [6, 2, 9, 1, 3, 5, 4, 8, 7] fitness: 29
# individuo: [4, 1, 8, 2, 5, 9, 7, 6, 3] fitness: 29
# individuo: [7, 1, 8, 4, 3, 2, 5, 9, 6] fitness: 29
# individuo: [4, 6, 1, 9, 5, 8, 7, 2, 3] fitness: 29
# individuo: [6, 7, 8, 1, 9, 2, 4, 5, 3] fitness: 29
# individuo: [1, 9, 3, 8, 5, 7, 6, 4, 2] fitness: 29
# individuo: [3, 9, 7, 2, 6, 8, 5, 1, 4] fitness: 29
# individuo: [1, 7, 5, 2, 4, 6, 9, 3, 8] fitness: 29
# individuo: [6, 4, 8, 9, 3, 7, 2, 5, 1] fitness: 29
# individuo: [2, 6, 4, 5, 8, 3, 7, 9, 1] fitness: 29
# individuo: [6, 3, 9, 8, 2, 4, 1, 7, 5] fitness: 29
# individuo: [8, 1, 7, 6, 9, 3, 4, 2, 5] fitness: 29
# individuo: [4, 3, 6, 5, 9, 2, 8, 7, 1] fitness: 29
# individuo: [9, 5, 8, 4, 7, 1, 3, 6, 2] fitness: 29
# individuo: [3, 2, 8, 6, 7, 1, 9, 5, 4] fitness: 29
# individuo: [4, 3, 8, 2, 6, 1, 5, 7, 9] fitness: 29
# individuo: [3, 6, 5, 2, 4, 7, 9, 1, 8] fitness: 29
# individuo: [7, 1, 2, 8, 5, 3, 6, 9, 4] fitness: 29
# individuo: [5, 7, 3, 8, 9, 1, 4, 2, 6] fitness: 29
# individuo: [2, 1, 7, 4, 6, 8, 3, 9, 5] fitness: 29
# individuo: [7, 9, 5, 1, 4, 2, 8, 3, 6] fitness: 29
# individuo: [4, 8, 6, 9, 5, 2, 7, 1, 3] fitness: 29
# individuo: [8, 3, 7, 2, 9, 6, 5, 4, 1] fitness: 29
# individuo: [1, 8, 3, 9, 7, 5, 2, 4, 6] fitness: 29
# individuo: [6, 4, 9, 1, 5, 7, 8, 2, 3] fitness: 29
# individuo: [7, 4, 3, 1, 9, 5, 6, 2, 8] fitness: 29
# individuo: [4, 2, 9, 3, 1, 6, 8, 5, 7] fitness: 29
# individuo: [2, 8, 4, 1, 6, 9, 7, 3, 5] fitness: 29
# individuo: [9, 1, 4, 8, 7, 3, 5, 2, 6] fitness: 29
# individuo: [2, 6, 3, 5, 7, 9, 4, 8, 1] fitness: 29
# individuo: [3, 9, 7, 1, 4, 5, 6, 2, 8] fitness: 29
# individuo: [4, 7, 1, 9, 5, 6, 8, 3, 2] fitness: 30
# individuo: [1, 5, 4, 7, 2, 8, 3, 6, 9] fitness: 30
# individuo: [5, 9, 7, 3, 8, 2, 4, 6, 1] fitness: 30
# individuo: [3, 7, 9, 4, 2, 8, 6, 1, 5] fitness: 30
# individuo: [3, 6, 2, 8, 5, 4, 7, 9, 1] fitness: 30
# individuo: [7, 6, 4, 1, 9, 3, 2, 8, 5] fitness: 30
# individuo: [8, 5, 4, 1, 7, 3, 6, 9, 2] fitness: 30
# individuo: [8, 2, 4, 9, 5, 7, 1, 3, 6] fitness: 30
# individuo: [8, 1, 4, 5, 9, 3, 6, 7, 2] fitness: 30
# individuo: [8, 4, 9, 7, 1, 6, 3, 5, 2] fitness: 30
# individuo: [2, 4, 9, 6, 3, 5, 7, 1, 8] fitness: 30
# individuo: [6, 5, 2, 8, 7, 3, 1, 9, 4] fitness: 30
# individuo: [8, 2, 9, 7, 1, 5, 6, 3, 4] fitness: 30
# individuo: [8, 5, 7, 4, 6, 1, 3, 9, 2] fitness: 30
# individuo: [7, 3, 5, 2, 8, 1, 4, 6, 9] fitness: 30
# individuo: [7, 3, 6, 2, 4, 9, 8, 1, 5] fitness: 30
# individuo: [7, 5, 8, 2, 9, 6, 1, 4, 3] fitness: 30
# individuo: [5, 8, 3, 4, 7, 9, 1, 6, 2] fitness: 31
# individuo: [4, 8, 3, 1, 9, 6, 2, 5, 7] fitness: 31
# individuo: [7, 1, 2, 6, 5, 8, 3, 9, 4] fitness: 31
# individuo: [4, 7, 9, 3, 5, 8, 2, 6, 1] fitness: 31
# individuo: [7, 9, 4, 5, 3, 6, 1, 8, 2] fitness: 31
# individuo: [5, 7, 1, 8, 9, 2, 6, 3, 4] fitness: 31
# individuo: [2, 8, 1, 7, 9, 4, 5, 6, 3] fitness: 31
# individuo: [3, 5, 7, 1, 9, 2, 4, 6, 8] fitness: 31
# individuo: [9, 5, 7, 1, 4, 8, 3, 6, 2] fitness: 31
# individuo: [6, 1, 4, 9, 5, 2, 7, 8, 3] fitness: 31
# individuo: [4, 8, 5, 1, 6, 9, 2, 3, 7] fitness: 31
# individuo: [5, 9, 1, 8, 7, 3, 4, 6, 2] fitness: 31
# individuo: [8, 2, 5, 6, 9, 1, 4, 7, 3] fitness: 31
# individuo: [1, 5, 7, 9, 3, 6, 2, 8, 4] fitness: 31
# individuo: [3, 8, 6, 7, 5, 1, 9, 2, 4] fitness: 31
# individuo: [4, 3, 8, 1, 5, 6, 2, 9, 7] fitness: 31
# individuo: [1, 7, 4, 5, 6, 8, 3, 9, 2] fitness: 31
# individuo: [7, 1, 9, 3, 4, 6, 8, 5, 2] fitness: 31
# individuo: [7, 3, 8, 1, 5, 6, 9, 4, 2] fitness: 31
# individuo: [5, 3, 2, 8, 6, 9, 1, 7, 4] fitness: 31
# individuo: [7, 1, 5, 8, 3, 2, 9, 6, 4] fitness: 31
# individuo: [3, 6, 9, 1, 7, 5, 4, 2, 8] fitness: 31
# individuo: [2, 8, 3, 9, 7, 4, 1, 6, 5] fitness: 31
# individuo: [3, 5, 8, 7, 4, 6, 1, 9, 2] fitness: 31
# individuo: [6, 5, 2, 7, 8, 1, 4, 9, 3] fitness: 31
# individuo: [9, 5, 2, 6, 8, 3, 7, 1, 4] fitness: 31
# individuo: [5, 4, 6, 3, 7, 1, 8, 9, 2] fitness: 31
# individuo: [2, 8, 7, 4, 6, 5, 1, 9, 3] fitness: 31
# individuo: [3, 4, 9, 6, 1, 7, 5, 2, 8] fitness: 31
# individuo: [8, 2, 9, 6, 3, 1, 7, 4, 5] fitness: 31
# individuo: [4, 1, 8, 3, 6, 7, 2, 5, 9] fitness: 31
# individuo: [3, 9, 4, 1, 6, 7, 5, 8, 2] fitness: 31
# individuo: [7, 5, 3, 8, 1, 4, 9, 6, 2] fitness: 31
# individuo: [3, 9, 7, 1, 4, 5, 8, 2, 6] fitness: 31
# individuo: [6, 2, 8, 1, 4, 7, 9, 5, 3] fitness: 31
# individuo: [7, 5, 8, 4, 3, 2, 9, 1, 6] fitness: 31
# individuo: [5, 3, 2, 8, 6, 7, 1, 9, 4] fitness: 31
# individuo: [3, 4, 2, 9, 1, 7, 5, 8, 6] fitness: 31
# individuo: [6, 8, 4, 3, 7, 1, 9, 5, 2] fitness: 32
# individuo: [1, 9, 4, 5, 7, 6, 2, 8, 3] fitness: 32
# individuo: [7, 2, 5, 8, 6, 1, 4, 9, 3] fitness: 32
# individuo: [7, 5, 9, 3, 8, 2, 6, 4, 1] fitness: 32
# individuo: [7, 3, 6, 2, 4, 8, 5, 1, 9] fitness: 32
# individuo: [4, 5, 1, 9, 7, 2, 6, 3, 8] fitness: 32
# individuo: [8, 2, 7, 4, 9, 3, 1, 5, 6] fitness: 32
# individuo: [9, 2, 5, 6, 4, 7, 3, 8, 1] fitness: 32
# individuo: [3, 6, 1, 9, 4, 5, 2, 8, 7] fitness: 32
# individuo: [3, 9, 1, 5, 8, 4, 2, 6, 7] fitness: 32
# individuo: [2, 8, 1, 3, 7, 5, 9, 4, 6] fitness: 32
# individuo: [6, 5, 1, 9, 3, 7, 8, 2, 4] fitness: 32
# individuo: [8, 6, 3, 9, 2, 5, 7, 1, 4] fitness: 32
# individuo: [7, 2, 8, 5, 3, 6, 1, 4, 9] fitness: 32
# individuo: [9, 3, 7, 1, 6, 8, 2, 4, 5] fitness: 32
# individuo: [8, 1, 5, 7, 3, 6, 9, 2, 4] fitness: 32
# individuo: [1, 5, 7, 4, 9, 2, 8, 6, 3] fitness: 32
# individuo: [1, 6, 2, 7, 9, 4, 8, 3, 5] fitness: 32
# individuo: [4, 1, 8, 6, 5, 3, 9, 2, 7] fitness: 33
# individuo: [6, 4, 3, 8, 5, 1, 7, 2, 9] fitness: 33
# individuo: [9, 3, 8, 5, 2, 7, 1, 4, 6] fitness: 33
# individuo: [3, 7, 9, 5, 2, 8, 1, 6, 4] fitness: 33
# individuo: [9, 3, 5, 8, 1, 4, 7, 2, 6] fitness: 33
# individuo: [1, 8, 3, 7, 6, 2, 9, 5, 4] fitness: 33
# individuo: [8, 2, 6, 5, 3, 4, 9, 1, 7] fitness: 33
# individuo: [1, 9, 2, 6, 4, 5, 7, 3, 8] fitness: 33
# individuo: [1, 5, 6, 2, 7, 4, 9, 3, 8] fitness: 33
# individuo: [4, 5, 1, 8, 3, 7, 6, 2, 9] fitness: 33
# individuo: [5, 8, 4, 1, 7, 3, 9, 6, 2] fitness: 33
# individuo: [6, 3, 8, 4, 1, 7, 9, 2, 5] fitness: 33
# individuo: [5, 3, 9, 2, 6, 7, 4, 1, 8] fitness: 33
# individuo: [6, 9, 4, 7, 3, 5, 2, 8, 1] fitness: 33
# individuo: [8, 4, 7, 1, 6, 3, 2, 9, 5] fitness: 33
# individuo: [4, 1, 9, 2, 6, 7, 5, 8, 3] fitness: 33
# individuo: [5, 9, 2, 8, 1, 7, 6, 4, 3] fitness: 34
# individuo: [6, 3, 9, 4, 2, 7, 5, 1, 8] fitness: 34
# individuo: [7, 3, 5, 6, 2, 8, 4, 9, 1] fitness: 34
# individuo: [5, 8, 4, 1, 9, 2, 6, 7, 3] fitness: 34
# individuo: [3, 9, 4, 2, 6, 1, 8, 5, 7] fitness: 34
# individuo: [6, 1, 8, 5, 9, 3, 4, 7, 2] fitness: 34
# individuo: [9, 2, 6, 3, 8, 4, 5, 1, 7] fitness: 34
# individuo: [1, 8, 5, 6, 2, 7, 4, 9, 3] fitness: 34
# individuo: [2, 9, 4, 7, 1, 5, 6, 3, 8] fitness: 34
# individuo: [3, 7, 4, 9, 5, 8, 2, 6, 1] fitness: 34
# individuo: [7, 4, 9, 2, 5, 1, 6, 8, 3] fitness: 34
# individuo: [9, 5, 1, 7, 4, 6, 2, 8, 3] fitness: 34
# individuo: [6, 7, 3, 8, 1, 5, 4, 9, 2] fitness: 34
# individuo: [5, 9, 2, 8, 1, 3, 6, 4, 7] fitness: 34
# individuo: [5, 7, 1, 8, 6, 2, 9, 4, 3] fitness: 34
# individuo: [4, 2, 7, 3, 5, 8, 1, 9, 6] fitness: 34
# individuo: [2, 5, 8, 1, 6, 9, 3, 7, 4] fitness: 34
# individuo: [4, 5, 7, 3, 6, 9, 1, 8, 2] fitness: 34
# individuo: [1, 7, 4, 8, 5, 9, 2, 6, 3] fitness: 34
# individuo: [5, 9, 2, 7, 6, 1, 8, 3, 4] fitness: 35
# individuo: [8, 3, 5, 1, 6, 4, 9, 2, 7] fitness: 35
# individuo: [4, 6, 3, 8, 7, 1, 9, 2, 5] fitness: 35
# individuo: [6, 2, 5, 8, 3, 9, 4, 1, 7] fitness: 35
# individuo: [4, 2, 8, 1, 9, 5, 6, 3, 7] fitness: 35
# individuo: [6, 3, 8, 4, 5, 7, 2, 9, 1] fitness: 35
# individuo: [4, 8, 7, 2, 6, 3, 9, 1, 5] fitness: 35
# individuo: [7, 3, 8, 1, 9, 5, 4, 6, 2] fitness: 35
# individuo: [4, 7, 3, 6, 1, 8, 5, 2, 9] fitness: 35
# individuo: [1, 9, 2, 8, 5, 3, 7, 4, 6] fitness: 35
# individuo: [7, 4, 6, 3, 5, 9, 1, 8, 2] fitness: 35
# individuo: [9, 3, 7, 1, 8, 4, 5, 2, 6] fitness: 35
# individuo: [8, 3, 9, 4, 6, 2, 5, 1, 7] fitness: 35
# individuo: [7, 2, 9, 1, 5, 3, 6, 4, 8] fitness: 35
# individuo: [5, 7, 1, 6, 3, 9, 2, 4, 8] fitness: 35
# individuo: [6, 1, 7, 3, 2, 9, 4, 8, 5] fitness: 35
# individuo: [4, 8, 7, 3, 6, 1, 9, 2, 5] fitness: 35
# individuo: [2, 9, 3, 8, 4, 6, 5, 1, 7] fitness: 35
# individuo: [8, 1, 5, 3, 7, 2, 9, 4, 6] fitness: 36
# individuo: [2, 7, 3, 6, 1, 9, 5, 8, 4] fitness: 36
# individuo: [4, 7, 3, 5, 6, 1, 9, 2, 8] fitness: 36
# individuo: [1, 9, 3, 6, 2, 8, 4, 7, 5] fitness: 36
# individuo: [4, 2, 8, 5, 9, 1, 7, 3, 6] fitness: 36
# individuo: [7, 1, 6, 2, 9, 5, 4, 8, 3] fitness: 36
# individuo: [7, 3, 9, 1, 6, 2, 5, 8, 4] fitness: 37
# individuo: [5, 3, 7, 6, 2, 8, 1, 9, 4] fitness: 37
# individuo: [5, 8, 3, 9, 2, 7, 1, 4, 6] fitness: 37
# individuo: [3, 8, 4, 7, 2, 9, 1, 5, 6] fitness: 37
# individuo: [7, 2, 9, 1, 5, 4, 8, 3, 6] fitness: 37
# individuo: [7, 5, 2, 8, 1, 6, 3, 9, 4] fitness: 37
# individuo: [6, 4, 5, 9, 1, 8, 2, 7, 3] fitness: 37
# individuo: [3, 9, 4, 7, 2, 6, 1, 8, 5] fitness: 38
# individuo: [5, 1, 6, 4, 8, 2, 9, 3, 7] fitness: 38
# individuo: [4, 8, 3, 9, 1, 6, 2, 7, 5] fitness: 39
# individuo: [4, 9, 3, 8, 1, 7, 2, 6, 5] fitness: 39
# poblacion
# [[1, 2, 9, 4, 5, 8, 6, 3, 7], [7, 6, 5, 8, 2, 4, 1, 3, 9], [7, 9, 4, 8, 3, 1, 5, 6, 2], [1, 6, 8, 5, 9, 7, 3, 2, 4], [5, 9, 2, 7, 6, 1, 8, 3, 4], [6, 3, 5, 2, 1, 8, 7, 4, 9], [3, 2, 4, 9, 7, 1, 6, 5, 8], [1, 8, 7, 3, 4, 2, 5, 9, 6], [9, 8, 5, 7, 3, 6, 2, 1, 4], [6, 8, 4, 3, 7, 1, 9, 5, 2], [1, 2, 8, 6, 9, 7, 4, 5, 3], [5, 1, 4, 6, 8, 9, 2, 3, 7], [9, 6, 8, 3, 1, 7, 2, 4, 5], [1, 5, 7, 4, 8, 9, 3, 6, 2], [4, 7, 1, 9, 5, 6, 8, 3, 2], [5, 8, 3, 4, 7, 9, 1, 6, 2], [7, 8, 5, 3, 4, 2, 1, 6, 9], [3, 1, 9, 6, 8, 4, 5, 7, 2], [9, 8, 4, 5, 1, 7, 3, 2, 6], [1, 4, 9, 2, 3, 6, 5, 7, 8], [4, 8, 3, 1, 9, 6, 2, 5, 7], [7, 1, 2, 6, 5, 8, 3, 9, 4], [6, 5, 9, 2, 1, 7, 8, 4, 3], [1, 8, 7, 9, 4, 6, 2, 3, 5], [1, 5, 8, 4, 9, 7, 3, 2, 6], [4, 9, 8, 1, 2, 7, 6, 5, 3], [7, 3, 4, 2, 1, 6, 8, 9, 5], [5, 9, 2, 8, 1, 7, 6, 4, 3], [9, 8, 2, 6, 1, 3, 4, 7, 5], [6, 3, 9, 4, 2, 7, 5, 1, 8], [9, 1, 2, 8, 6, 3, 4, 5, 7], [7, 3, 9, 1, 6, 2, 5, 8, 4], [4, 7, 9, 3, 5, 8, 2, 6, 1], [7, 9, 4, 5, 3, 6, 1, 8, 2], [6, 9, 4, 1, 5, 2, 3, 8, 7], [9, 5, 1, 3, 2, 4, 7, 8, 6], [6, 2, 5, 1, 9, 8, 7, 4, 3], [3, 1, 6, 8, 4, 5, 2, 7, 9], [8, 3, 5, 1, 6, 4, 9, 2, 7], [4, 2, 6, 1, 8, 9, 7, 5, 3], [6, 5, 1, 2, 9, 8, 4, 3, 7], [2, 8, 6, 1, 4, 5, 3, 7, 9], [1, 7, 9, 5, 6, 2, 4, 8, 3], [5, 7, 1, 8, 9, 2, 6, 3, 4], [6, 9, 1, 7, 8, 4, 5, 2, 3], [1, 7, 3, 2, 6, 9, 8, 5, 4], [4, 5, 7, 6, 9, 2, 1, 3, 8], [4, 1, 8, 6, 5, 3, 9, 2, 7], [8, 2, 9, 4, 3, 6, 7, 5, 1], [1, 5, 4, 7, 2, 8, 3, 6, 9], [4, 6, 8, 9, 3, 7, 2, 5, 1], [9, 2, 6, 7, 4, 1, 3, 5, 8], [5, 9, 7, 3, 8, 2, 4, 6, 1], [6, 4, 3, 8, 5, 1, 7, 2, 9], [7, 3, 5, 6, 2, 8, 4, 9, 1], [8, 9, 7, 3, 1, 6, 5, 4, 2], [2, 8, 1, 7, 9, 4, 5, 6, 3], [5, 8, 4, 1, 9, 2, 6, 7, 3], [8, 3, 1, 4, 9, 2, 5, 6, 7], [4, 2, 7, 1, 3, 6, 5, 9, 8], [3, 1, 8, 2, 4, 6, 9, 7, 5], [5, 1, 3, 9, 8, 6, 7, 2, 4], [3, 2, 6, 4, 5, 9, 1, 7, 8], [8, 5, 1, 7, 9, 6, 2, 4, 3], [7, 4, 6, 9, 8, 3, 1, 5, 2], [9, 3, 8, 5, 2, 7, 1, 4, 6], [1, 2, 8, 3, 9, 4, 7, 5, 6], [3, 7, 9, 4, 2, 8, 6, 1, 5], [7, 6, 5, 4, 1, 9, 8, 2, 3], [1, 9, 4, 5, 7, 6, 2, 8, 3], [5, 7, 9, 8, 1, 3, 2, 6, 4], [1, 2, 6, 4, 3, 5, 8, 7, 9], [8, 6, 7, 1, 5, 4, 9, 3, 2], [3, 5, 7, 1, 9, 2, 4, 6, 8], [6, 8, 5, 4, 9, 2, 3, 1, 7], [1, 6, 3, 5, 8, 4, 7, 9, 2], [9, 5, 7, 1, 4, 8, 3, 6, 2], [3, 9, 4, 2, 6, 1, 8, 5, 7], [1, 3, 5, 9, 2, 7, 4, 6, 8], [8, 9, 1, 6, 2, 5, 4, 3, 7], [3, 6, 2, 8, 5, 4, 7, 9, 1], [7, 9, 1, 3, 2, 4, 8, 6, 5], [8, 5, 2, 3, 7, 9, 1, 6, 4], [3, 6, 1, 2, 8, 9, 5, 7, 4], [6, 1, 4, 9, 5, 2, 7, 8, 3], [6, 7, 3, 2, 1, 9, 8, 5, 4], [7, 2, 5, 8, 6, 1, 4, 9, 3], [5, 3, 7, 6, 2, 8, 1, 9, 4], [7, 4, 8, 6, 2, 1, 3, 5, 9], [2, 6, 7, 8, 5, 9, 4, 3, 1], [1, 5, 2, 9, 6, 3, 4, 7, 8], [8, 1, 5, 9, 6, 4, 7, 3, 2], [4, 1, 6, 9, 5, 2, 3, 8, 7], [3, 4, 1, 9, 8, 5, 7, 6, 2], [8, 9, 2, 5, 7, 1, 4, 3, 6], [2, 3, 4, 6, 8, 7, 5, 9, 1], [3, 6, 1, 7, 2, 4, 5, 8, 9], [4, 2, 9, 7, 6, 3, 1, 5, 8], [4, 8, 5, 1, 6, 9, 2, 3, 7], [8, 6, 4, 3, 7, 9, 5, 1, 2], [5, 9, 1, 8, 7, 3, 4, 6, 2], [4, 1, 6, 7, 8, 3, 5, 2, 9], [3, 1, 7, 4, 2, 6, 9, 5, 8], [9, 7, 8, 3, 2, 1, 6, 5, 4], [8, 6, 3, 4, 7, 9, 5, 2, 1], [9, 5, 1, 2, 3, 7, 6, 4, 8], [6, 9, 4, 1, 5, 3, 2, 8, 7], [1, 3, 6, 4, 5, 2, 7, 8, 9], [6, 2, 9, 1, 3, 5, 4, 8, 7], [6, 8, 3, 1, 4, 2, 7, 9, 5], [1, 6, 8, 3, 9, 7, 4, 2, 5], [2, 3, 7, 6, 5, 9, 8, 4, 1], [1, 8, 6, 7, 2, 3, 9, 5, 4], [5, 8, 3, 9, 2, 7, 1, 4, 6], [8, 2, 5, 6, 9, 1, 4, 7, 3], [3, 2, 1, 7, 9, 5, 6, 8, 4], [5, 6, 8, 7, 2, 3, 9, 1, 4], [4, 6, 3, 8, 7, 1, 9, 2, 5], [9, 7, 4, 3, 5, 2, 6, 1, 8], [2, 3, 8, 7, 6, 1, 5, 9, 4], [1, 5, 7, 9, 3, 6, 2, 8, 4], [7, 5, 9, 3, 8, 2, 6, 4, 1], [3, 8, 6, 7, 5, 1, 9, 2, 4], [3, 7, 9, 5, 2, 8, 1, 6, 4], [4, 2, 6, 7, 8, 9, 3, 5, 1], [4, 1, 8, 9, 5, 3, 7, 6, 2], [5, 4, 2, 3, 7, 1, 8, 9, 6], [8, 9, 7, 2, 4, 5, 6, 3, 1], [4, 3, 8, 1, 5, 6, 2, 9, 7], [4, 1, 8, 2, 5, 9, 7, 6, 3], [7, 6, 4, 1, 9, 3, 2, 8, 5], [7, 3, 6, 2, 4, 8, 5, 1, 9], [6, 2, 5, 8, 3, 9, 4, 1, 7], [1, 7, 4, 5, 6, 8, 3, 9, 2], [4, 1, 7, 9, 5, 8, 6, 3, 2], [3, 8, 7, 2, 9, 5, 6, 4, 1], [1, 7, 6, 3, 5, 2, 4, 9, 8], [6, 1, 8, 5, 9, 3, 4, 7, 2 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 30
#      27 poblacion = seleccion_y_reproduccion(poblacion)
#      28 poblacion = mutacion(poblacion)
# ---> 30 poblacion_evaluada = [(i, calcular_fitness(i)) for i in poblacion ]
#      31 poblacion_ordenada  = sorted(poblacion_evaluada, key=ordenar_por_segundo_elemento)
#      33 print(f"generacion no: {numero_generacion}")
#
# Cell In[10], line 30, in <listcomp>(.0)
#      27 poblacion = seleccion_y_reproduccion(poblacion)
#      28 poblacion = mutacion(poblacion)
# ---> 30 poblacion_evaluada = [(i, calcular_fitness(i)) for i in poblacion ]
#      31 poblacion_ordenada  = sorted(poblacion_evaluada, key=ordenar_por_segundo_elemento)
#      33 print(f"generacion no: {numero_generacion}")
#
# Cell In[3], line 32, in calcular_fitness(individuo)
#      30 distance = 0
#      31 for i in range(len(individuo) - 1):
# ---> 32     distance += abs(individuo[i] - individuo[i + 1])
#      33 return distance
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'
